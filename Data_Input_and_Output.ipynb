# %% [markdown]
# # HTML Output

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')

# %%
! pip install lxml

# %%
! pip install html5lib

# %%
! pip install BeautifulSoup4

# %%
df[0]
# Out:
#                          Bank NameBank           CityCity StateSt  CertCert  \
# 0                    Almena State Bank             Almena      KS     15426
# 1           First City Bank of Florida  Fort Walton Beach      FL     16748
# 2                 The First State Bank      Barboursville      WV     14361
# 3                   Ericson State Bank            Ericson      NE     18265
# 4     City National Bank of New Jersey             Newark      NJ     21111
# ..                                 ...                ...     ...       ...
# 558                 Superior Bank, FSB           Hinsdale      IL     32646
# 559                Malta National Bank              Malta      OH      6629
# 560    First Alliance Bank & Trust Co.         Manchester      NH     34264
# 561  National State Bank of Metropolis         Metropolis      IL      3815
# 562                   Bank of Honolulu           Honolulu      HI     21029
#
# ...

# %%
pd.set_option('display.max_rows',563)
pd.set_option('display.max_columns', 563)

# %% [markdown]
# # CSV
# CSV input

# %%
df = df[0]

# %%
df.head()
# Out:
#                       Bank NameBank           CityCity StateSt  CertCert  \
# 0                 Almena State Bank             Almena      KS     15426
# 1        First City Bank of Florida  Fort Walton Beach      FL     16748
# 2              The First State Bank      Barboursville      WV     14361
# 3                Ericson State Bank            Ericson      NE     18265
# 4  City National Bank of New Jersey             Newark      NJ     21111
#
#       Acquiring InstitutionAI Closing DateClosing  FundFund
# 0                 Equity Bank    October 23, 2020     10538
# 1   United Fidelity Bank, fsb    October 16, 2020     10537
# 2              MVB Bank, Inc.       April 3, 2020     10536
# 3  Farmers and Merchants Bank   February 14, 2020     10535
# 4             Industrial Bank    November 1, 2019     10534

# %%
new_names = ['Bank_name', 'City', 'State', 'Cert', 'IntsitutionAi', 'Closing_Date', 'Fund']

# %%
df.columns = new_names

# %%
df.head()
# Out:
#                           Bank_name               City State   Cert  \
# 0                 Almena State Bank             Almena    KS  15426
# 1        First City Bank of Florida  Fort Walton Beach    FL  16748
# 2              The First State Bank      Barboursville    WV  14361
# 3                Ericson State Bank            Ericson    NE  18265
# 4  City National Bank of New Jersey             Newark    NJ  21111
#
#                 IntsitutionAi       Closing_Date   Fund
# 0                 Equity Bank   October 23, 2020  10538
# 1   United Fidelity Bank, fsb   October 16, 2020  10537
# 2              MVB Bank, Inc.      April 3, 2020  10536
# 3  Farmers and Merchants Bank  February 14, 2020  10535
# 4             Industrial Bank   November 1, 2019  10534

# %%
df['Closing_Date'].dtypes
# Out:
# dtype('O')

# %%
df['date'] = pd.to_datetime(df['Closing_Date'])

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#                           Bank_name               City State   Cert  \
# 0                 Almena State Bank             Almena    KS  15426
# 1        First City Bank of Florida  Fort Walton Beach    FL  16748
# 2              The First State Bank      Barboursville    WV  14361
# 3                Ericson State Bank            Ericson    NE  18265
# 4  City National Bank of New Jersey             Newark    NJ  21111
#
#                 IntsitutionAi       Closing_Date   Fund       date
# 0                 Equity Bank   October 23, 2020  10538 2020-10-23
# 1   United Fidelity Bank, fsb   October 16, 2020  10537 2020-10-16
# 2              MVB Bank, Inc.      April 3, 2020  10536 2020-04-03
# 3  Farmers and Merchants Bank  February 14, 2020  10535 2020-02-14
# 4             Industrial Bank   November 1, 2019  10534 2019-11-01

# %%
df['date'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
#convert datetime object to string
df['date'] = df['date'].astype('string')

# %%
df['date'].dtypes
# Out:
# string[python]

# %%
df['Year'] =df['date'].apply(lambda x: x.split('-')[0])
df['Month'] =df['date'].apply(lambda x: x.split('-')[1])
df['Day'] =df['date'].apply(lambda x: x.split('-')[2])

# %%
df.head()
# Out:
#                           Bank_name               City State   Cert  \
# 0                 Almena State Bank             Almena    KS  15426
# 1        First City Bank of Florida  Fort Walton Beach    FL  16748
# 2              The First State Bank      Barboursville    WV  14361
# 3                Ericson State Bank            Ericson    NE  18265
# 4  City National Bank of New Jersey             Newark    NJ  21111
#
#                 IntsitutionAi       Closing_Date   Fund        date  Year  \
# 0                 Equity Bank   October 23, 2020  10538  2020-10-23  2020
# 1   United Fidelity Bank, fsb   October 16, 2020  10537  2020-10-16  2020
# 2              MVB Bank, Inc.      April 3, 2020  10536  2020-04-03  2020
# 3  Farmers and Merchants Bank  February 14, 2020  10535  2020-02-14  2020
# 4             Industrial Bank   November 1, 2019  10534  2019-11-01  2019
#
#   Month Day
# 0    10  23
# 1    10  16
# 2    04  03
# 3    02  14
# 4    11  01

# %%
df.drop('date', axis =1, inplace = True)

# %%
df.head()
# Out:
#                           Bank_name               City State   Cert  \
# 0                 Almena State Bank             Almena    KS  15426
# 1        First City Bank of Florida  Fort Walton Beach    FL  16748
# 2              The First State Bank      Barboursville    WV  14361
# 3                Ericson State Bank            Ericson    NE  18265
# 4  City National Bank of New Jersey             Newark    NJ  21111
#
#                 IntsitutionAi       Closing_Date   Fund  Year Month Day
# 0                 Equity Bank   October 23, 2020  10538  2020    10  23
# 1   United Fidelity Bank, fsb   October 16, 2020  10537  2020    10  16
# 2              MVB Bank, Inc.      April 3, 2020  10536  2020    04  03
# 3  Farmers and Merchants Bank  February 14, 2020  10535  2020    02  14
# 4             Industrial Bank   November 1, 2019  10534  2019    11  01

# %%
for idx, row in df.iterrows():
    print(row['State'])
# Out:
# KS
# FL
# WV
# NE
# NJ
# OH
# KY
# TX
# IL
# KS
# IL
# WI
# LA
# UT
# IL
# NJ
# AR
# GA
# PA
# TN
# WI
# WA
# GA
# CO
# IL
# PR
# GA
# IL
# FL
# MN
# CA
# IL
# MD
# IL
# GA
# OK
# FL
# IL
# MD
# OH
# IL
# SC
# PA
# VA
# ID
# OK
# IL
# TX
# FL
# TX
# CT
# AZ
# TN
# WI
# FL
# TN
# NV
# WI
# AZ
# GA
# NC
# GA
# NC
# FL
# FL
# KY
# AZ
# GA
# IL
# MN
# WA
# MO
# GA
# IL
# FL
# PA
# MO
# FL
# FL
# IL
# MO
# MN
# IL
# GA
# IL
# KS
# GA
# GA
# FL
# MO
# GA
# TN
# GA
# FL
# NC
# IL
# SC
# OK
# AL
# FL
# CA
# SC
# MN
# MD
# MD
# NJ
# MI
# IL
# GA
# IL
# GA
# MN
# GA
# IN
# IL
# TN
# MN
# TN
# FL
# PA
# GA
# FL
# AZ
# FL
# LA
# IA
# GA
# UT
# NE
# IL
# CO
# GA
# GA
# FL
# IL
# NJ
# NC
# GA
# MO
# MN
# TX
# CA
# VA
# FL
# GA
# GA
# IL
# GA
# FL
# PA
# KS
# WA
# IL
# IN
# SC
# VA
# CO
# FL
# FL
# AZ
# FL
# GA
# GA
# CO
# CO
# IL
# GA
# FL
# GA
# SC
# WA
# WA
# GA
# GA
# FL
# MI
# GA
# GA
# FL
# FL
# MS
# MN
# AL
# AL
# GA
# GA
# NV
# IL
# IL
# WI
# OK
# IL
# CA
# CA
# GA
# GA
# CA
# WI
# MI
# FL
# ...

# %%
# Saving as csv
df.to_csv('example' ,index=False)

# %%
df = pd.read_csv('example')
df
# Out:
#                              Bank_name               City State   Cert  \
# 0                    Almena State Bank             Almena    KS  15426
# 1           First City Bank of Florida  Fort Walton Beach    FL  16748
# 2                 The First State Bank      Barboursville    WV  14361
# 3                   Ericson State Bank            Ericson    NE  18265
# 4     City National Bank of New Jersey             Newark    NJ  21111
# ..                                 ...                ...   ...    ...
# 558                 Superior Bank, FSB           Hinsdale    IL  32646
# 559                Malta National Bank              Malta    OH   6629
# 560    First Alliance Bank & Trust Co.         Manchester    NH  34264
# 561  National State Bank of Metropolis         Metropolis    IL   3815
# 562                   Bank of Honolulu           Honolulu    HI  21029
#
#                            IntsitutionAi   Fund                  date  \
# ...

# %% [markdown]
# # Excel

# %%
pd.read_excel('Excel_sample.xlsx',sheet_name='Sheet1')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
#To get names of columns
df.columns
# Out:
# Index(['Bank_name', 'City', 'State', 'Cert', 'IntsitutionAi', 'Fund', 'date',
#        'Year'],
#       dtype='object')

# %%
new_columns = ['Bank', 'City', 'State', 'Cert',
       'Acquiring Institution', 'Closing Date', 'Fund']
df.columns = new_columns
df.head(1)

# %%
#to obtain more information about your dat frame columns
df.info

# %% [markdown]
# # groupby method

# %%
group_df = df.groupby('State')

# %%
group_df.mean()
